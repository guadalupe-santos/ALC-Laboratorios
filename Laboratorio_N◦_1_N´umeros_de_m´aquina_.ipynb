# %% [markdown]
# <a href="https://colab.research.google.com/github/guadalupe-santos/ALC-Laboratorios/blob/main/Laboratorio_N%E2%97%A6_1_N%C2%B4umeros_de_m%C2%B4aquina_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1

# %%
x = 0.1 + 0.2
y = 0.3
print(x == y)
print(format(x,'.20f'))
print(format(y,'.20f'))
# Out:
# False
# 0.30000000000000004441
# 0.29999999999999998890

# %% [markdown]
# Ejercicio 2

# %%
a = 1.0
while a > 0.1: #al restar py agrega decimales, nunca llega al valor exacto 0.1
 print(a)
 a = a - 0.1
print('fin')
# Out:
# 1.0
# 0.9
# 0.8
# 0.7000000000000001
# 0.6000000000000001
# 0.5000000000000001
# 0.40000000000000013
# 0.30000000000000016
# 0.20000000000000015
# 0.10000000000000014
# fin

# %% [markdown]
# Ejercicio 3

# %% [markdown]
# ** IEEE 754 precisión simple ** estandar que usan las computadoras

# %%
print(0.3 + 0.25)
print(0.3 - 0.25)
# Out:
# 0.55
# 0.04999999999999999

# %% [markdown]
# Parte entera de 0.25 -> 0 primer dígito antes de la coma
#
# 0.25x2 = 0.5
# primer dígito binario: 0 -> num a la izq
# 0.5x2 = 1.0 -> mult de vuelta parte decimal
# segundo digito binario: 1
# 0.0 -> termine, parte decimal que sobro es 0
# => 0.01
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mantisa: 1.0
# Exponente: -2

# %% [markdown]
# 0.3 -> parte entera 0
# 0.3x2 = 0.6 -> 1er num binario: 0
# 0.6x2 = 1,2 -> 2do: 1
# nunca llego a parte decimal 0.
# 0.3 -> 0.01......
# no es posible mantisa finita

# %% [markdown]
# Ejercicio 4

# %%
import numpy as np

# %%
np.sqrt(2)**2-2
# Out:
# np.float64(4.440892098500626e-16)

# %% [markdown]
# x va de 0 a 0.00000005 -> **la notación científica es: e**
# 5x10^-8 -> 5e-8

# %%
import matplotlib.pyplot as plt
#a
x = np.linspace(0, 5e-8,100) #100 valores equiespaciados entre 0 y 5e-8
y = np.sqrt(2*x**2+1)-1
plt.plot(x,y)

# %%
#b
x = np.linspace(0, 5e-8,100) #100 valores equiespaciados entre 0 y 5e-8
y = (2*x**2)/(np.sqrt(2*x**2+1)+1)
plt.plot(x,y)
